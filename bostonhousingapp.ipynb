# %% [markdown]
# ***GENERATED CODE FOR bostonhousingapp PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***AUTOML FUNCTIONS***

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run bostonhousingappHooks.ipynb
try:
	
except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRAIN MODEL***

# %%
#%run bostonhousingappHooks.ipynb
try:
	#mlPreExecutionHook()

	dataAutoML=XG-Boost-classifier(autofe, ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT"], "MEDV")

	#mlPostExecutionHook(dataAutoML)

except Exception as ex: 
	logging.error(ex)
